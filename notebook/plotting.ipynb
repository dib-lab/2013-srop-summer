# %%
cd /usr/local/notebooks
# Out:
# /usr/local/notebooks

# %%
ls
# Out:
# course-00-update-notebooks.ipynb  README.txt

# %%
# !pip install git+https://github.com/ged-lab/screed.git
# Out:
# Downloading/unpacking git+https://github.com/ged-lab/screed.git
#   Cloning https://github.com/ged-lab/screed.git to /tmp/pip-OhLgRP-build
#   Running setup.py egg_info for package from git+https://github.com/ged-lab/screed.git
# ...
#   Running setup.py install for screed
# ...
# Cleaning up...

# %%
import screed

# %%
ls /mnt
# Out:
# ecoli-reads-5m-dn-paired.fa.gz  g.21/  g.31/  lost+found/

# %%
alias
# Out:
# Total number of aliases:
#  12
# [('cat', 'cat'),
#  ('cp', 'cp -i'),
#  ('ldir', 'ls -F -o --color %l | grep /$'),
#  ('lf', 'ls -F -o --color %l | grep ^-'),
#  ('lk', 'ls -F -o --color %l | grep ^l'),
#  ('ll', 'ls -F -o --color'),
#  ('ls', 'ls -F --color'),
#  ('lx', 'ls -F -o --color %l | grep ^-..x'),
#  ('mkdir', 'mkdir'),
#  ('mv', 'mv -i'),
#  ('rm', 'rm -i'),
#  ('rmdir', 'rmdir')]

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %bookmark  %cd  %clear  %colors  %config  %connect_info  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %install_default_config  %install_ext  %install_profiles  %killbgscripts  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %lsmagic  %macro  %magic  %man  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %run  %save  %sc  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%bash  %%capture  %%file  %%javascript  %%latex  %%perl  %%prun  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%timeit
#
# ...

# %%
contig_lengths_k21 = [ len(r.sequence) for r in screed.open('/mnt/g.21/contigs.fa') ]

# %%
contig_lengths_k21.sort(reverse=True)

# %%
contig_lengths_k21[:20]
# Out:
# [36754,
#  24392,
#  22257,
#  21752,
#  21682,
#  21584,
#  21428,
#  21245,
#  21185,
#  20324,
#  20056,
#  19724,
#  19587,
#  17825,
#  17805,
#  17683,
#  17652,
#  17479,
#  16818,
#  16770]

# %%
plot(contig_lengths_k21[:20], '.')

# %%
contig_lengths_k31 = [ len(r.sequence) for r in screed.open('/mnt/g.31/contigs.fa') ]

# %%
contig_lengths_k31.sort(reverse=True)

# %%
plot(contig_lengths_k31[:20], '.')

# %%
plot(contig_lengths_k31[:20], '.')
plot(contig_lengths_k21[:20], '.')

# %%
plot(contig_lengths_k31[:20], 'x', color="red")
plot(contig_lengths_k21[:20], '.')

# %%
title("E.coli assembly k21 vs. k31")
plot(contig_lengths_k31[:20], '.', label="k31")
plot(contig_lengths_k21[:20], '.', label="k21")
legend()

# %%
title("E.coli assembly k21 vs. k31")
plot(contig_lengths_k31[:20], '.-', label="k31")
plot(contig_lengths_k21[:20], 'x-', label="k21")
legend()

# %%
# %load http://matplotlib.org/mpl_examples/api/barchart_demo.py

# %%
#!/usr/bin/env python
# a bar plot with errorbars
import numpy as np
import matplotlib.pyplot as plt

N = 5
menMeans = (20, 35, 30, 35, 27)
menStd =   (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)
rects1 = ax.bar(ind, menMeans, width, color='r', yerr=menStd)

womenMeans = (25, 32, 34, 20, 25)
womenStd =   (3, 5, 2, 3, 3)
rects2 = ax.bar(ind+width, womenMeans, width, color='y', yerr=womenStd)

# add some
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('G1', 'G2', 'G3', 'G4', 'G5') )

ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %%
title("E.coli assembly k21 vs. k31")
plot(contig_lengths_k31[:20], '.-', label="k31")
plot(contig_lengths_k21[:20], 'x-', label="k21")
legend()
savefig("asm_k21.k31.png")

# %%
from IPython.display import Image

# %%
Image(filename="asm_k21.k31.png")

# %%
savefig?
